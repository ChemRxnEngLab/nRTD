# %%
import wandb
import pandas as pd
import ICIW_Plots
import matplotlib.pyplot as plt
from wandb_util import extract_run_data

plt.style.use("ICIWstyle")
plt.rcParams["font.size"] = 7

# %%
run_id = "xoqfjwvh"
run_url = f"ice_ulm/HSA_MGA_nRTD/{run_id}"

# %%
api = wandb.Api()
run = api.run(run_url)

# %%
run_name, run_data = extract_run_data(run_url)
print(run_data)
# Out:
#              name  epoch  test/loss  train/loss  trainer/global_step  n_in  \
# 0  breezy-sun-230  10000   0.000002    0.000002                10000   161
#
#       t_in  n_out     t_out  n_kernel t_kernel  delta_t_out kernel_sizes  \
# 0  [0, 40]    481  [0, 120]       321  [0, 80]         0.25        [321]
#
#   kernel_times  learning_rate  use_scheduler                  scheduler_kwargs
# 0    [[0, 80]]          0.004           True  {'factor': 0.6, 'patience': 100}

# %%
orig_data = pd.DataFrame(run.scan_history(keys=["train/loss", "epoch"]))

# %%
data = orig_data.copy()
data.loc[400:, "epoch"] += 20000
data.loc[800:, "epoch"] += 20000
data.loc[1200:, "epoch"] += 20000

# %%
fig = ICIW_Plots.figure()
ax = ICIW_Plots.make_square_ax(
    fig,
    ax_width=5.5 * ICIW_Plots.cm2inch,
    left_h=0.5,
    xlabel="epoch",
    ylabel="MSE / 1",
    yscale="log",
)
ax.plot(data["epoch"], data["train/loss"])
# ax.plot(data.loc[-1, "epoch"], run_data["test/loss"], "o")
ax.legend()
plt.savefig("4bar_heated_loss.png", dpi=600)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
